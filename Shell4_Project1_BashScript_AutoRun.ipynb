# %% [markdown]
# **Historical Weather Forecast Comparison to Actuals**

# %% [markdown]
# #Exercise 1-4: Schedule Bash script `rx_poc.sh` to run every day at noon local time

# %% [markdown]
# Two method add header/ columns into log file:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Create cron job:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Exercise 5: Create a script to report historical forecasting accuracy

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Exercise 6: Create a script to report weekly statistics of historical forecasting accuracy

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
