# %% [markdown]
# #`cron`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##`crontab -e`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# `0 21 * * * echo "Welcome to cron" >> /tmp/echo.txt`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##`crontab -l`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Schedule shell script

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# `#! /bin/bash`\
# `# print the current date time`\
# `date`\
# `# print the disk free statistics`\
# `df -h`

# %% [markdown]
# ##`crontab -r` delete the current crontab

# %% [markdown]
# #Cheat Sheet `cron`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
